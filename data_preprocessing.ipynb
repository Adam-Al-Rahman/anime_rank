# %% [markdown]
# <h3 style="color: #7aa2f7; font-weight: bold;">Import Libraries</h3>

# %%
from library import pd_read_csv, pd_dataframe
from library import CsvSniffer, pd_series


from core import rr_unique, rr_display, rr_str_series, rr_clean_alt_list, rr_to_series, rr_remove_none

# %% [markdown]
# <h3 style="color: #7aa2f7; font-weight: bold;">About Dataset</h3>

# %%
# know the delimiter of the csv file

dataset_mal_top2000_anime = open("dataset/mal_top2000_anime.csv", 'r')
dataset_mal_top2000_anime_first_row = dataset_mal_top2000_anime.readline(1)

sniffer = CsvSniffer()
dataset_first_row = sniffer.sniff(dataset_mal_top2000_anime_first_row)
dataset_mal_top2000_anime_delimiter = dataset_first_row.delimiter
print(f"`dataset/mal_top2000_anime.csv` delimiter: {dataset_mal_top2000_anime_delimiter}")
# Out:
# `dataset/mal_top2000_anime.csv` delimiter: ,

# %% [markdown]
# <div style="
#   color: #9aa5ce;
#   font-family: Fira Code;
#   font-weight: 500;
# ">
# <ul>
# <li>Dataset Info</li>
#   <ul>
#   <li>Column value = None, if the value is not assigned</li>
#   <li>Structured Data</li>
#   <li>File type: <code style="color: #89ddff">*.csv</code></li>
#   <li>Delimiter: <code style="color: #89ddff">,</code></li>
#   </ul>
# </ul>

# %% [markdown]
# <h3 style="color: #7aa2f7; font-weight: bold;">Dataset</h3>

# %%
# Dataset credit
brunobacelardc_myanimelist_top2000_anime = pd_read_csv("dataset/mal_top2000_anime.csv", delimiter = dataset_mal_top2000_anime_delimiter)

# Alias to credited dataset
anime_dataset = brunobacelardc_myanimelist_top2000_anime

# %% [markdown]
# <h2 style="color: #7aa2f7; font-weight: bold;" align="center"><u>Preprocessing Dataset</u></h2>

# %% [markdown]
# <h3 style="color: #7aa2f7; font-weight: bold;">Data Cleansing</h3>

# %%
rr_display(anime_dataset.head(5))
# Out:
# <style type="text/css">
# #T_00989 th {
#   text-align: left;
# }
# #T_00989_row0_col0, #T_00989_row0_col1, #T_00989_row0_col2, #T_00989_row0_col3, #T_00989_row0_col4, #T_00989_row0_col5, #T_00989_row0_col6, #T_00989_row0_col7, #T_00989_row0_col8, #T_00989_row0_col9, #T_00989_row0_col10, #T_00989_row0_col11, #T_00989_row1_col0, #T_00989_row1_col1, #T_00989_row1_col2, #T_00989_row1_col3, #T_00989_row1_col4, #T_00989_row1_col5, #T_00989_row1_col6, #T_00989_row1_col7, #T_00989_row1_col8, #T_00989_row1_col9, #T_00989_row1_col10, #T_00989_row1_col11, #T_00989_row2_col0, #T_00989_row2_col1, #T_00989_row2_col2, #T_00989_row2_col3, #T_00989_row2_col4, #T_00989_row2_col5, #T_00989_row2_col6, #T_00989_row2_col7, #T_00989_row2_col8, #T_00989_row2_col9, #T_00989_row2_col10, #T_00989_row2_col11, #T_00989_row3_col0, #T_00989_row3_col1, #T_00989_row3_col2, #T_00989_row3_col3, #T_00989_row3_col4, #T_00989_row3_col5, #T_00989_row3_col6, #T_00989_row3_col7, #T_00989_row3_col8, #T_00989_row3_col9, #T_00989_row3_col10, #T_00989_row3_col11, #T_00989_row4_col0, #T_00989_row4_col1, #T_00989_row4_col2, #T_00989_row4_col3, #T_00989_row4_col4, #T_00989_row4_col5, #T_00989_row4_col6, #T_00989_row4_col7, #T_00989_row4_col8, #T_00989_row4_col9, #T_00989_row4_col10, #T_00989_row4_col11 {
#   text-align: left;
# }
# </style>
# <table id="T_00989">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_00989_level0_col0" class="col_heading level0 col0" >Unnamed: 0</th>
#       <th id="T_00989_level0_col1" class="col_heading level0 col1" >Name</th>
#       <th id="T_00989_level0_col2" class="col_heading level0 col2" >Type</th>
#       <th id="T_00989_level0_col3" class="col_heading level0 col3" >Score</th>
#       <th id="T_00989_level0_col4" class="col_heading level0 col4" >Score Rank</th>
#       <th id="T_00989_level0_col5" class="col_heading level0 col5" >Popularity Rank</th>
#       <th id="T_00989_level0_col6" class="col_heading level0 col6" >Air Date</th>
#       <th id="T_00989_level0_col7" class="col_heading level0 col7" >Studio</th>
#       <th id="T_00989_level0_col8" class="col_heading level0 col8" >Num. of episodes</th>
#       <th id="T_00989_level0_col9" class="col_heading level0 col9" >Genres</th>
#       <th id="T_00989_level0_col10" class="col_heading level0 col10" >Theme(s)</th>
#       <th id="T_00989_level0_col11" class="col_heading level0 col11" >Demographic</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_00989_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_00989_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_00989_row0_col1" class="data row0 col1" >Fullmetal Alchemist: Brotherhood</td>
#       <td id="T_00989_row0_col2" class="data row0 col2" >TV</td>
#       <td id="T_00989_row0_col3" class="data row0 col3" >9.140000</td>
#       <td id="T_00989_row0_col4" class="data row0 col4" >1</td>
#       <td id="T_00989_row0_col5" class="data row0 col5" >3</td>
#       <td id="T_00989_row0_col6" class="data row0 col6" >Apr 5, 2009 to Jul 4, 2010</td>
#       <td id="T_00989_row0_col7" class="data row0 col7" >['Bones']</td>
#       <td id="T_00989_row0_col8" class="data row0 col8" >64</td>
#       <td id="T_00989_row0_col9" class="data row0 col9" >['Action', 'Adventure', 'Drama', 'Fantasy']</td>
#       <td id="T_00989_row0_col10" class="data row0 col10" >['Military']</td>
#       <td id="T_00989_row0_col11" class="data row0 col11" >Shounen</td>
#     </tr>
#     <tr>
#       <th id="T_00989_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_00989_row1_col0" class="data row1 col0" >1</td>
#       <td id="T_00989_row1_col1" class="data row1 col1" >Spy x Family</td>
#       <td id="T_00989_row1_col2" class="data row1 col2" >TV</td>
#       <td id="T_00989_row1_col3" class="data row1 col3" >9.090000</td>
#       <td id="T_00989_row1_col4" class="data row1 col4" >2</td>
#       <td id="T_00989_row1_col5" class="data row1 col5" >350</td>
#       <td id="T_00989_row1_col6" class="data row1 col6" >Apr 9, 2022 to ?</td>
#       <td id="T_00989_row1_col7" class="data row1 col7" >['Wit Studio', '            CloverWorks']</td>
#       <td id="T_00989_row1_col8" class="data row1 col8" >12</td>
#       <td id="T_00989_row1_col9" class="data row1 col9" >['Action', 'Comedy']</td>
#       <td id="T_00989_row1_col10" class="data row1 col10" >['Childcare']</td>
#       <td id="T_00989_row1_col11" class="data row1 col11" >Shounen</td>
#     </tr>
#     <tr>
#       <th id="T_00989_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_00989_row2_col0" class="data row2 col0" >2</td>
#       <td id="T_00989_row2_col1" class="data row2 col1" >Shingeki no Kyojin Season 3 Part 2</td>
#       <td id="T_00989_row2_col2" class="data row2 col2" >TV</td>
#       <td id="T_00989_row2_col3" class="data row2 col3" >9.080000</td>
#       <td id="T_00989_row2_col4" class="data row2 col4" >3</td>
#       <td id="T_00989_row2_col5" class="data row2 col5" >32</td>
#       <td id="T_00989_row2_col6" class="data row2 col6" >Apr 29, 2019 to Jul 1, 2019</td>
#       <td id="T_00989_row2_col7" class="data row2 col7" >['Wit Studio']</td>
#       <td id="T_00989_row2_col8" class="data row2 col8" >10</td>
#       <td id="T_00989_row2_col9" class="data row2 col9" >['Action', 'Drama']</td>
#       <td id="T_00989_row2_col10" class="data row2 col10" >['Gore', 'Military', 'Survival']</td>
#       <td id="T_00989_row2_col11" class="data row2 col11" >Shounen</td>
#     </tr>
#     <tr>
#       <th id="T_00989_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_00989_row3_col0" class="data row3 col0" >3</td>
#       <td id="T_00989_row3_col1" class="data row3 col1" >Steins;Gate</td>
#       <td id="T_00989_row3_col2" class="data row3 col2" >TV</td>
#       <td id="T_00989_row3_col3" class="data row3 col3" >9.080000</td>
#       <td id="T_00989_row3_col4" class="data row3 col4" >4</td>
#       <td id="T_00989_row3_col5" class="data row3 col5" >13</td>
#       <td id="T_00989_row3_col6" class="data row3 col6" >Apr 6, 2011 to Sep 14, 2011</td>
#       <td id="T_00989_row3_col7" class="data row3 col7" >['White Fox']</td>
#       <td id="T_00989_row3_col8" class="data row3 col8" >24</td>
#       <td id="T_00989_row3_col9" class="data row3 col9" >['Drama', 'Sci-Fi', 'Suspense']</td>
#       <td id="T_00989_row3_col10" class="data row3 col10" >['Psychological', 'Time Travel']</td>
#       <td id="T_00989_row3_col11" class="data row3 col11" >None</td>
#     </tr>
#     <tr>
#       <th id="T_00989_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_00989_row4_col0" class="data row4 col0" >4</td>
#       <td id="T_00989_row4_col1" class="data row4 col1" >Gintama°</td>
#       <td id="T_00989_row4_col2" class="data row4 col2" >TV</td>
#       <td id="T_00989_row4_col3" class="data row4 col3" >9.080000</td>
#       <td id="T_00989_row4_col4" class="data row4 col4" >5</td>
#       <td id="T_00989_row4_col5" class="data row4 col5" >335</td>
#       <td id="T_00989_row4_col6" class="data row4 col6" >Apr 8, 2015 to Mar 30, 2016</td>
#       <td id="T_00989_row4_col7" class="data row4 col7" >['Bandai Namco Pictures']</td>
#       <td id="T_00989_row4_col8" class="data row4 col8" >51</td>
#       <td id="T_00989_row4_col9" class="data row4 col9" >['Action', 'Comedy', 'Sci-Fi']</td>
#       <td id="T_00989_row4_col10" class="data row4 col10" >['Gag Humor', 'Historical', 'Parody', 'Samurai']</td>
#       <td id="T_00989_row4_col11" class="data row4 col11" >Shounen</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# <h4 style="color: #7aa2f7; font-weight: bold;">Data Extraction</h4>
#
# <div style="
#   color: #9aa5ce;
#   font-family: Fira Code;
#   font-weight: 500;
# ">
#
# <p>Extracting only the required data.</p>
#
#
# <p style="font-size: 20px;">Required Dataset Column</p>
#
# - <code style="color: #7aa2f7;">Types</code>: What the anime's type of media is (e.g. a television anime, a movie, a music video, etcetera)
# - <code style="color: #7aa2f7;">Score</code>: The anime's score, calculated using MAL's weighted scoring.
# - <code style="color: #7aa2f7;">Score Rank</code>: The anime's rank, based on its score.
# - <code style="color: #7aa2f7;">Studio</code>: The studio(s) that made the anime.
# - <code style="color: #7aa2f7;">Num. of episodes</code>: How many episodes the anime has.
# - <code style="color: #7aa2f7;">Genres</code>: The anime's genres, formatted as a list. An entry with no genres registered in the website will have a single list with the string 'None' as its value.
# - <code style="color: #7aa2f7;">Popularity Rank</code> : The anime's rank, based on its popularity.
#
# </div>

# %%
# required data
required_dataset_column = [
    "Name", # Required only to create new csv file
    "Genres",
    "Studio",
    "Type",
    "Score",
    "Score Rank",
    "Num. of episodes",
    "Popularity Rank"
]


anime_dataset = anime_dataset[required_dataset_column]
rr_display(anime_dataset.head())
# Out:
# <style type="text/css">
# #T_2620a th {
#   text-align: left;
# }
# #T_2620a_row0_col0, #T_2620a_row0_col1, #T_2620a_row0_col2, #T_2620a_row0_col3, #T_2620a_row0_col4, #T_2620a_row0_col5, #T_2620a_row0_col6, #T_2620a_row0_col7, #T_2620a_row1_col0, #T_2620a_row1_col1, #T_2620a_row1_col2, #T_2620a_row1_col3, #T_2620a_row1_col4, #T_2620a_row1_col5, #T_2620a_row1_col6, #T_2620a_row1_col7, #T_2620a_row2_col0, #T_2620a_row2_col1, #T_2620a_row2_col2, #T_2620a_row2_col3, #T_2620a_row2_col4, #T_2620a_row2_col5, #T_2620a_row2_col6, #T_2620a_row2_col7, #T_2620a_row3_col0, #T_2620a_row3_col1, #T_2620a_row3_col2, #T_2620a_row3_col3, #T_2620a_row3_col4, #T_2620a_row3_col5, #T_2620a_row3_col6, #T_2620a_row3_col7, #T_2620a_row4_col0, #T_2620a_row4_col1, #T_2620a_row4_col2, #T_2620a_row4_col3, #T_2620a_row4_col4, #T_2620a_row4_col5, #T_2620a_row4_col6, #T_2620a_row4_col7 {
#   text-align: left;
# }
# </style>
# <table id="T_2620a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2620a_level0_col0" class="col_heading level0 col0" >Name</th>
#       <th id="T_2620a_level0_col1" class="col_heading level0 col1" >Genres</th>
#       <th id="T_2620a_level0_col2" class="col_heading level0 col2" >Studio</th>
#       <th id="T_2620a_level0_col3" class="col_heading level0 col3" >Type</th>
#       <th id="T_2620a_level0_col4" class="col_heading level0 col4" >Score</th>
#       <th id="T_2620a_level0_col5" class="col_heading level0 col5" >Score Rank</th>
#       <th id="T_2620a_level0_col6" class="col_heading level0 col6" >Num. of episodes</th>
#       <th id="T_2620a_level0_col7" class="col_heading level0 col7" >Popularity Rank</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2620a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_2620a_row0_col0" class="data row0 col0" >Fullmetal Alchemist: Brotherhood</td>
#       <td id="T_2620a_row0_col1" class="data row0 col1" >['Action', 'Adventure', 'Drama', 'Fantasy']</td>
#       <td id="T_2620a_row0_col2" class="data row0 col2" >['Bones']</td>
#       <td id="T_2620a_row0_col3" class="data row0 col3" >TV</td>
#       <td id="T_2620a_row0_col4" class="data row0 col4" >9.140000</td>
#       <td id="T_2620a_row0_col5" class="data row0 col5" >1</td>
#       <td id="T_2620a_row0_col6" class="data row0 col6" >64</td>
#       <td id="T_2620a_row0_col7" class="data row0 col7" >3</td>
#     </tr>
#     <tr>
#       <th id="T_2620a_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_2620a_row1_col0" class="data row1 col0" >Spy x Family</td>
#       <td id="T_2620a_row1_col1" class="data row1 col1" >['Action', 'Comedy']</td>
#       <td id="T_2620a_row1_col2" class="data row1 col2" >['Wit Studio', '            CloverWorks']</td>
#       <td id="T_2620a_row1_col3" class="data row1 col3" >TV</td>
#       <td id="T_2620a_row1_col4" class="data row1 col4" >9.090000</td>
#       <td id="T_2620a_row1_col5" class="data row1 col5" >2</td>
#       <td id="T_2620a_row1_col6" class="data row1 col6" >12</td>
#       <td id="T_2620a_row1_col7" class="data row1 col7" >350</td>
#     </tr>
#     <tr>
#       <th id="T_2620a_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_2620a_row2_col0" class="data row2 col0" >Shingeki no Kyojin Season 3 Part 2</td>
#       <td id="T_2620a_row2_col1" class="data row2 col1" >['Action', 'Drama']</td>
#       <td id="T_2620a_row2_col2" class="data row2 col2" >['Wit Studio']</td>
#       <td id="T_2620a_row2_col3" class="data row2 col3" >TV</td>
#       <td id="T_2620a_row2_col4" class="data row2 col4" >9.080000</td>
#       <td id="T_2620a_row2_col5" class="data row2 col5" >3</td>
#       <td id="T_2620a_row2_col6" class="data row2 col6" >10</td>
#       <td id="T_2620a_row2_col7" class="data row2 col7" >32</td>
#     </tr>
#     <tr>
#       <th id="T_2620a_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_2620a_row3_col0" class="data row3 col0" >Steins;Gate</td>
#       <td id="T_2620a_row3_col1" class="data row3 col1" >['Drama', 'Sci-Fi', 'Suspense']</td>
#       <td id="T_2620a_row3_col2" class="data row3 col2" >['White Fox']</td>
#       <td id="T_2620a_row3_col3" class="data row3 col3" >TV</td>
#       <td id="T_2620a_row3_col4" class="data row3 col4" >9.080000</td>
#       <td id="T_2620a_row3_col5" class="data row3 col5" >4</td>
#       <td id="T_2620a_row3_col6" class="data row3 col6" >24</td>
#       <td id="T_2620a_row3_col7" class="data row3 col7" >13</td>
#     </tr>
#     <tr>
#       <th id="T_2620a_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_2620a_row4_col0" class="data row4 col0" >Gintama°</td>
#       <td id="T_2620a_row4_col1" class="data row4 col1" >['Action', 'Comedy', 'Sci-Fi']</td>
#       <td id="T_2620a_row4_col2" class="data row4 col2" >['Bandai Namco Pictures']</td>
#       <td id="T_2620a_row4_col3" class="data row4 col3" >TV</td>
#       <td id="T_2620a_row4_col4" class="data row4 col4" >9.080000</td>
#       <td id="T_2620a_row4_col5" class="data row4 col5" >5</td>
#       <td id="T_2620a_row4_col6" class="data row4 col6" >51</td>
#       <td id="T_2620a_row4_col7" class="data row4 col7" >335</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Extracting unique element in anime_dataset["Studio"]

anime_dataset_studio = list(anime_dataset["Studio"])
anime_dataset_studio_unique = rr_unique(anime_dataset_studio, True, ",")

print(f"Number of Unique Studio: {len(anime_dataset_studio_unique)}\n\n| Unique Studio(s) |\n--------------------")
print(anime_dataset_studio_unique)
# Out:
# Number of Unique Studio: 224
#
# | Unique Studio(s) |
# --------------------
# ['bones', 'wit studio', 'cloverworks', 'white fox', 'bandai namco pictures', 'sunrise', 'madhouse', 'tms entertainment', 'k-factory', 'kitty film mitaka studio', 'a-1 pictures', 'shaft', 'kyoto animation', 'mappa', 'ufotable', 'comix wave films', 'studio lan', 'studio ghibli', 'production i.g', 'pierrot plus', 'studio signpost', 'studio bind', 'olm', 'p.i.c.s.', 'studio deen', 'artland', 'tokyo movie shinsha', 'b.cmay pictures', 'studio pierrot', 'none', 'kinema citrus', 'khara', '"brains base"', 'gainax', 'shuka', 'toei animation', 'tatsunoko production', 'studio chizu', 'david production', 'studio voln', 'j.c.staff', 'c-station', 'lerche', 'shin-ei animation', 'manglobe', 'haoliners animation league', 'hal film maker', 'geno studio', 'egg firm', 'zero-g', 'platinum vision', 'synergysp', 'p.a. works', 'orange', 'nippon animation', 'silver link.', '8bit', 'feel.', 'lidenfilms', 'hololive production', 'topcraft', 'satelight', 'graphinica', 'motion magic', 'xebec', 'aic', 'trans arts', 'marvy jack', 'gonzo', 'tezuka productions', 'gallop', 'studio comet', 'a.c.g.t.', 'mushi production', 'studio hibari', 'imagin', 'tencent animation & comics', 'china literature limited', 'colored pencil animation', 'nut', 'sparkly key animation studio', 'shirogumi', 'science saru', 'studio 4°c', 'troyca', 'actas', 'telescreen', 'clap', 'yumeta company', 'nippon ramayana film co.', 'telecom animation film', 'pastel', 'seven arcs', 'bibury animation studios', 'magic bus', 'ajia-do', 'tyo animations', 'triangle staff', 'trigger', 'sanzigen', 'studio rikka', 'geek toys', 'oh! production', 'e&g films', 'studio kai', 'studio gokumi', 'appp', 'doga kobo', 'group tac', 'studio junio', 'purple cow studio japan', 'm.s.c', 'bee train', 'radix', 'encourage films', 'nomad', 'square enix', 'lapin track', 'g&g entertainment', 'hoods drifters studio', 'cygamespictures', 'flat studio', 'tokyo kids', 'minami machi bugyousho', 'production ims', 'nice boat animation', 'samsara animation studio', 'gohands', 'aic asta', 'naz', 'lay-duce', 'fanworks', 'djinn power', 'marza animation planet', 'studio kafka', 'hornets', 'anpro', 'phoenix entertainment', 'production doa', 'pine jam', 'dmm.futureworks', 'ascension', 'aic spirits', 'bestack', 'daume', 'arms', 'kitty films', 'polygon pictures', 'imagineer', 'animation do', 'zexcs', 'c2c', '10gauge', 'studio durian', 'aic classic', 'passione', 'yokohama animation lab', 'nakamura production', 'studio blanc', 'studio 3hz', 'planet cartoon', 'visual 80', 'bridge', 'production reed', 'lidenfilms kyoto studio', 'larx entertainment', 'hoods entertainment', 'bee media', 'code', 'dwarf', 'enishiya', 'palm studio', 'bigfirebird animation', 'october media', 'rabbit machine', 'i.gzwei', 'l²studio', 'asread.', 'original force', 'wan wei mao donghua', 'connect', 'studio colorido', 'ezόla', 'studio pastoral', 'signal.md', 'fuji tv', 'filmony', 'dongwoo a&e', 'shanghai foch film and tv culture investment', 'ruo hong culture', 'grouper productions', 'yaoyorozu', 'paper plane animation studio', 'the answer studio', 'seven arcs pictures', 'b&t', 'axsiz', 'diomedéa', 'dle', 'twin engine', 'studio daisy', 'felix film', 'sunrise beyond', 'odolttogi', 'light chaser animation studios', 'tnk', 'nexus', 'lico', 'red dog culture house', 'picture magic', 'trif studio', 'sublimation', 'millepensee', 'life work', 'mili pictures', 'jcf', 'ordet', 'project no.9', 'square enix visual works', 'asahi production', 'digital frontier', 'studio puyukai', 'wulifang digital', 'gaina']

# %%
# Extracting unique element in anime_dataset["Genres"]

anime_dataset_genres = list(anime_dataset["Genres"])
anime_dataset_genres_unique = rr_unique(anime_dataset_genres, True, ",")

print(f"Number of Unique Genres: {len(anime_dataset_genres_unique)}\n\n| Unique Genres |\n--------------------")
print(anime_dataset_genres_unique)
# Out:
# Number of Unique Genres: 20
#
# | Unique Genres |
# --------------------
# ['action', 'adventure', 'drama', 'fantasy', 'comedy', 'sci-fi', 'suspense', 'romance', 'slice of life', 'supernatural', 'mystery', 'award winning', 'sports', 'ecchi', 'none', 'avant garde', 'horror', 'boys love', 'gourmet', 'girls love']

# %%
# Extracting unique element in anime_dataset["Type"]

anime_dataset_types = list(anime_dataset["Type"])
anime_dataset_types_unique = rr_unique(anime_dataset_types, True, ",")

print(f"Number of Unique Types: {len(anime_dataset_types_unique)}\n\n| Unique Types |\n--------------------")
(anime_dataset_types_unique)
# Out:
# Number of Unique Types: 6
#
# | Unique Types |
# --------------------
# ['tv', 'movie', 'ova', 'ona', 'special', 'music']

# %%
rr_display(anime_dataset.head())
# Out:
# <style type="text/css">
# #T_b04f3 th {
#   text-align: left;
# }
# #T_b04f3_row0_col0, #T_b04f3_row0_col1, #T_b04f3_row0_col2, #T_b04f3_row0_col3, #T_b04f3_row0_col4, #T_b04f3_row0_col5, #T_b04f3_row0_col6, #T_b04f3_row0_col7, #T_b04f3_row1_col0, #T_b04f3_row1_col1, #T_b04f3_row1_col2, #T_b04f3_row1_col3, #T_b04f3_row1_col4, #T_b04f3_row1_col5, #T_b04f3_row1_col6, #T_b04f3_row1_col7, #T_b04f3_row2_col0, #T_b04f3_row2_col1, #T_b04f3_row2_col2, #T_b04f3_row2_col3, #T_b04f3_row2_col4, #T_b04f3_row2_col5, #T_b04f3_row2_col6, #T_b04f3_row2_col7, #T_b04f3_row3_col0, #T_b04f3_row3_col1, #T_b04f3_row3_col2, #T_b04f3_row3_col3, #T_b04f3_row3_col4, #T_b04f3_row3_col5, #T_b04f3_row3_col6, #T_b04f3_row3_col7, #T_b04f3_row4_col0, #T_b04f3_row4_col1, #T_b04f3_row4_col2, #T_b04f3_row4_col3, #T_b04f3_row4_col4, #T_b04f3_row4_col5, #T_b04f3_row4_col6, #T_b04f3_row4_col7 {
#   text-align: left;
# }
# </style>
# <table id="T_b04f3">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b04f3_level0_col0" class="col_heading level0 col0" >Name</th>
#       <th id="T_b04f3_level0_col1" class="col_heading level0 col1" >Genres</th>
#       <th id="T_b04f3_level0_col2" class="col_heading level0 col2" >Studio</th>
#       <th id="T_b04f3_level0_col3" class="col_heading level0 col3" >Type</th>
#       <th id="T_b04f3_level0_col4" class="col_heading level0 col4" >Score</th>
#       <th id="T_b04f3_level0_col5" class="col_heading level0 col5" >Score Rank</th>
#       <th id="T_b04f3_level0_col6" class="col_heading level0 col6" >Num. of episodes</th>
#       <th id="T_b04f3_level0_col7" class="col_heading level0 col7" >Popularity Rank</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b04f3_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b04f3_row0_col0" class="data row0 col0" >Fullmetal Alchemist: Brotherhood</td>
#       <td id="T_b04f3_row0_col1" class="data row0 col1" >['Action', 'Adventure', 'Drama', 'Fantasy']</td>
#       <td id="T_b04f3_row0_col2" class="data row0 col2" >['Bones']</td>
#       <td id="T_b04f3_row0_col3" class="data row0 col3" >TV</td>
#       <td id="T_b04f3_row0_col4" class="data row0 col4" >9.140000</td>
#       <td id="T_b04f3_row0_col5" class="data row0 col5" >1</td>
#       <td id="T_b04f3_row0_col6" class="data row0 col6" >64</td>
#       <td id="T_b04f3_row0_col7" class="data row0 col7" >3</td>
#     </tr>
#     <tr>
#       <th id="T_b04f3_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_b04f3_row1_col0" class="data row1 col0" >Spy x Family</td>
#       <td id="T_b04f3_row1_col1" class="data row1 col1" >['Action', 'Comedy']</td>
#       <td id="T_b04f3_row1_col2" class="data row1 col2" >['Wit Studio', '            CloverWorks']</td>
#       <td id="T_b04f3_row1_col3" class="data row1 col3" >TV</td>
#       <td id="T_b04f3_row1_col4" class="data row1 col4" >9.090000</td>
#       <td id="T_b04f3_row1_col5" class="data row1 col5" >2</td>
#       <td id="T_b04f3_row1_col6" class="data row1 col6" >12</td>
#       <td id="T_b04f3_row1_col7" class="data row1 col7" >350</td>
#     </tr>
#     <tr>
#       <th id="T_b04f3_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_b04f3_row2_col0" class="data row2 col0" >Shingeki no Kyojin Season 3 Part 2</td>
#       <td id="T_b04f3_row2_col1" class="data row2 col1" >['Action', 'Drama']</td>
#       <td id="T_b04f3_row2_col2" class="data row2 col2" >['Wit Studio']</td>
#       <td id="T_b04f3_row2_col3" class="data row2 col3" >TV</td>
#       <td id="T_b04f3_row2_col4" class="data row2 col4" >9.080000</td>
#       <td id="T_b04f3_row2_col5" class="data row2 col5" >3</td>
#       <td id="T_b04f3_row2_col6" class="data row2 col6" >10</td>
#       <td id="T_b04f3_row2_col7" class="data row2 col7" >32</td>
#     </tr>
#     <tr>
#       <th id="T_b04f3_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_b04f3_row3_col0" class="data row3 col0" >Steins;Gate</td>
#       <td id="T_b04f3_row3_col1" class="data row3 col1" >['Drama', 'Sci-Fi', 'Suspense']</td>
#       <td id="T_b04f3_row3_col2" class="data row3 col2" >['White Fox']</td>
#       <td id="T_b04f3_row3_col3" class="data row3 col3" >TV</td>
#       <td id="T_b04f3_row3_col4" class="data row3 col4" >9.080000</td>
#       <td id="T_b04f3_row3_col5" class="data row3 col5" >4</td>
#       <td id="T_b04f3_row3_col6" class="data row3 col6" >24</td>
#       <td id="T_b04f3_row3_col7" class="data row3 col7" >13</td>
#     </tr>
#     <tr>
#       <th id="T_b04f3_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_b04f3_row4_col0" class="data row4 col0" >Gintama°</td>
#       <td id="T_b04f3_row4_col1" class="data row4 col1" >['Action', 'Comedy', 'Sci-Fi']</td>
#       <td id="T_b04f3_row4_col2" class="data row4 col2" >['Bandai Namco Pictures']</td>
#       <td id="T_b04f3_row4_col3" class="data row4 col3" >TV</td>
#       <td id="T_b04f3_row4_col4" class="data row4 col4" >9.080000</td>
#       <td id="T_b04f3_row4_col5" class="data row4 col5" >5</td>
#       <td id="T_b04f3_row4_col6" class="data row4 col6" >51</td>
#       <td id="T_b04f3_row4_col7" class="data row4 col7" >335</td>
#     </tr>
#   </tbody>
# </table>

# %%
# TODO(@Adam-Al-Rahaman): Remove this cell and change it with respectively column
# anime_dataset["column_name"] = anime_dataset["column_name"].apply(eval), if
# overcome the @warning: `SettingWithCopyWarning`,
# @ref: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
updated_required_data = {
    "Name": anime_dataset["Name"], # Required, because the update dataset will be exported to new csv file as `dataset/rr_anime_info.csv`
    "Genres": rr_str_series(anime_dataset["Genres"], strip_white_space = True, to_lower=True),
    "Studio": rr_str_series(anime_dataset["Studio"], strip_white_space = True, to_lower=True),
    "Type": anime_dataset["Type"].str.lower(),
    "Score": anime_dataset["Score"],
    "Score Rank": anime_dataset["Score Rank"],
    "Num. of episodes": anime_dataset["Num. of episodes"],
    "Popularity Rank": anime_dataset["Popularity Rank"]
}

updated_required_dataset = pd_dataframe(updated_required_data)
rr_display(updated_required_dataset.head())
# Out:
# <style type="text/css">
# #T_7f1c1 th {
#   text-align: left;
# }
# #T_7f1c1_row0_col0, #T_7f1c1_row0_col1, #T_7f1c1_row0_col2, #T_7f1c1_row0_col3, #T_7f1c1_row0_col4, #T_7f1c1_row0_col5, #T_7f1c1_row0_col6, #T_7f1c1_row0_col7, #T_7f1c1_row1_col0, #T_7f1c1_row1_col1, #T_7f1c1_row1_col2, #T_7f1c1_row1_col3, #T_7f1c1_row1_col4, #T_7f1c1_row1_col5, #T_7f1c1_row1_col6, #T_7f1c1_row1_col7, #T_7f1c1_row2_col0, #T_7f1c1_row2_col1, #T_7f1c1_row2_col2, #T_7f1c1_row2_col3, #T_7f1c1_row2_col4, #T_7f1c1_row2_col5, #T_7f1c1_row2_col6, #T_7f1c1_row2_col7, #T_7f1c1_row3_col0, #T_7f1c1_row3_col1, #T_7f1c1_row3_col2, #T_7f1c1_row3_col3, #T_7f1c1_row3_col4, #T_7f1c1_row3_col5, #T_7f1c1_row3_col6, #T_7f1c1_row3_col7, #T_7f1c1_row4_col0, #T_7f1c1_row4_col1, #T_7f1c1_row4_col2, #T_7f1c1_row4_col3, #T_7f1c1_row4_col4, #T_7f1c1_row4_col5, #T_7f1c1_row4_col6, #T_7f1c1_row4_col7 {
#   text-align: left;
# }
# </style>
# <table id="T_7f1c1">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7f1c1_level0_col0" class="col_heading level0 col0" >Name</th>
#       <th id="T_7f1c1_level0_col1" class="col_heading level0 col1" >Genres</th>
#       <th id="T_7f1c1_level0_col2" class="col_heading level0 col2" >Studio</th>
#       <th id="T_7f1c1_level0_col3" class="col_heading level0 col3" >Type</th>
#       <th id="T_7f1c1_level0_col4" class="col_heading level0 col4" >Score</th>
#       <th id="T_7f1c1_level0_col5" class="col_heading level0 col5" >Score Rank</th>
#       <th id="T_7f1c1_level0_col6" class="col_heading level0 col6" >Num. of episodes</th>
#       <th id="T_7f1c1_level0_col7" class="col_heading level0 col7" >Popularity Rank</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7f1c1_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_7f1c1_row0_col0" class="data row0 col0" >Fullmetal Alchemist: Brotherhood</td>
#       <td id="T_7f1c1_row0_col1" class="data row0 col1" >['action', 'adventure', 'drama', 'fantasy']</td>
#       <td id="T_7f1c1_row0_col2" class="data row0 col2" >['bones']</td>
#       <td id="T_7f1c1_row0_col3" class="data row0 col3" >tv</td>
#       <td id="T_7f1c1_row0_col4" class="data row0 col4" >9.140000</td>
#       <td id="T_7f1c1_row0_col5" class="data row0 col5" >1</td>
#       <td id="T_7f1c1_row0_col6" class="data row0 col6" >64</td>
#       <td id="T_7f1c1_row0_col7" class="data row0 col7" >3</td>
#     </tr>
#     <tr>
#       <th id="T_7f1c1_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_7f1c1_row1_col0" class="data row1 col0" >Spy x Family</td>
#       <td id="T_7f1c1_row1_col1" class="data row1 col1" >['action', 'comedy']</td>
#       <td id="T_7f1c1_row1_col2" class="data row1 col2" >['wit studio', 'cloverworks']</td>
#       <td id="T_7f1c1_row1_col3" class="data row1 col3" >tv</td>
#       <td id="T_7f1c1_row1_col4" class="data row1 col4" >9.090000</td>
#       <td id="T_7f1c1_row1_col5" class="data row1 col5" >2</td>
#       <td id="T_7f1c1_row1_col6" class="data row1 col6" >12</td>
#       <td id="T_7f1c1_row1_col7" class="data row1 col7" >350</td>
#     </tr>
#     <tr>
#       <th id="T_7f1c1_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_7f1c1_row2_col0" class="data row2 col0" >Shingeki no Kyojin Season 3 Part 2</td>
#       <td id="T_7f1c1_row2_col1" class="data row2 col1" >['action', 'drama']</td>
#       <td id="T_7f1c1_row2_col2" class="data row2 col2" >['wit studio']</td>
#       <td id="T_7f1c1_row2_col3" class="data row2 col3" >tv</td>
#       <td id="T_7f1c1_row2_col4" class="data row2 col4" >9.080000</td>
#       <td id="T_7f1c1_row2_col5" class="data row2 col5" >3</td>
#       <td id="T_7f1c1_row2_col6" class="data row2 col6" >10</td>
#       <td id="T_7f1c1_row2_col7" class="data row2 col7" >32</td>
#     </tr>
#     <tr>
#       <th id="T_7f1c1_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_7f1c1_row3_col0" class="data row3 col0" >Steins;Gate</td>
#       <td id="T_7f1c1_row3_col1" class="data row3 col1" >['drama', 'sci-fi', 'suspense']</td>
#       <td id="T_7f1c1_row3_col2" class="data row3 col2" >['white fox']</td>
#       <td id="T_7f1c1_row3_col3" class="data row3 col3" >tv</td>
#       <td id="T_7f1c1_row3_col4" class="data row3 col4" >9.080000</td>
#       <td id="T_7f1c1_row3_col5" class="data row3 col5" >4</td>
#       <td id="T_7f1c1_row3_col6" class="data row3 col6" >24</td>
#       <td id="T_7f1c1_row3_col7" class="data row3 col7" >13</td>
#     </tr>
#     <tr>
#       <th id="T_7f1c1_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_7f1c1_row4_col0" class="data row4 col0" >Gintama°</td>
#       <td id="T_7f1c1_row4_col1" class="data row4 col1" >['action', 'comedy', 'sci-fi']</td>
#       <td id="T_7f1c1_row4_col2" class="data row4 col2" >['bandai namco pictures']</td>
#       <td id="T_7f1c1_row4_col3" class="data row4 col3" >tv</td>
#       <td id="T_7f1c1_row4_col4" class="data row4 col4" >9.080000</td>
#       <td id="T_7f1c1_row4_col5" class="data row4 col5" >5</td>
#       <td id="T_7f1c1_row4_col6" class="data row4 col6" >51</td>
#       <td id="T_7f1c1_row4_col7" class="data row4 col7" >335</td>
#     </tr>
#   </tbody>
# </table>

# %%
# None value contain in Genres column
dataset_genres_none_val = updated_required_dataset["Genres"].apply(lambda x: 'none' in x)
rr_display(updated_required_dataset[dataset_genres_none_val])
# Out:
# <style type="text/css">
# #T_709b3 th {
#   text-align: left;
# }
# #T_709b3_row0_col0, #T_709b3_row0_col1, #T_709b3_row0_col2, #T_709b3_row0_col3, #T_709b3_row0_col4, #T_709b3_row0_col5, #T_709b3_row0_col6, #T_709b3_row0_col7, #T_709b3_row1_col0, #T_709b3_row1_col1, #T_709b3_row1_col2, #T_709b3_row1_col3, #T_709b3_row1_col4, #T_709b3_row1_col5, #T_709b3_row1_col6, #T_709b3_row1_col7, #T_709b3_row2_col0, #T_709b3_row2_col1, #T_709b3_row2_col2, #T_709b3_row2_col3, #T_709b3_row2_col4, #T_709b3_row2_col5, #T_709b3_row2_col6, #T_709b3_row2_col7, #T_709b3_row3_col0, #T_709b3_row3_col1, #T_709b3_row3_col2, #T_709b3_row3_col3, #T_709b3_row3_col4, #T_709b3_row3_col5, #T_709b3_row3_col6, #T_709b3_row3_col7, #T_709b3_row4_col0, #T_709b3_row4_col1, #T_709b3_row4_col2, #T_709b3_row4_col3, #T_709b3_row4_col4, #T_709b3_row4_col5, #T_709b3_row4_col6, #T_709b3_row4_col7, #T_709b3_row5_col0, #T_709b3_row5_col1, #T_709b3_row5_col2, #T_709b3_row5_col3, #T_709b3_row5_col4, #T_709b3_row5_col5, #T_709b3_row5_col6, #T_709b3_row5_col7, #T_709b3_row6_col0, #T_709b3_row6_col1, #T_709b3_row6_col2, #T_709b3_row6_col3, #T_709b3_row6_col4, #T_709b3_row6_col5, #T_709b3_row6_col6, #T_709b3_row6_col7, #T_709b3_row7_col0, #T_709b3_row7_col1, #T_709b3_row7_col2, #T_709b3_row7_col3, #T_709b3_row7_col4, #T_709b3_row7_col5, #T_709b3_row7_col6, #T_709b3_row7_col7, #T_709b3_row8_col0, #T_709b3_row8_col1, #T_709b3_row8_col2, #T_709b3_row8_col3, #T_709b3_row8_col4, #T_709b3_row8_col5, #T_709b3_row8_col6, #T_709b3_row8_col7, #T_709b3_row9_col0, #T_709b3_row9_col1, #T_709b3_row9_col2, #T_709b3_row9_col3, #T_709b3_row9_col4, #T_709b3_row9_col5, #T_709b3_row9_col6, #T_709b3_row9_col7, #T_709b3_row10_col0, #T_709b3_row10_col1, #T_709b3_row10_col2, #T_709b3_row10_col3, #T_709b3_row10_col4, #T_709b3_row10_col5, #T_709b3_row10_col6, #T_709b3_row10_col7, #T_709b3_row11_col0, #T_709b3_row11_col1, #T_709b3_row11_col2, #T_709b3_row11_col3, #T_709b3_row11_col4, #T_709b3_row11_col5, #T_709b3_row11_col6, #T_709b3_row11_col7, #T_709b3_row12_col0, #T_709b3_row12_col1, #T_709b3_row12_col2, #T_709b3_row12_col3, #T_709b3_row12_col4, #T_709b3_row12_col5, #T_709b3_row12_col6, #T_709b3_row12_col7, #T_709b3_row13_col0, #T_709b3_row13_col1, #T_709b3_row13_col2, #T_709b3_row13_col3, #T_709b3_row13_col4, #T_709b3_row13_col5, #T_709b3_row13_col6, #T_709b3_row13_col7, #T_709b3_row14_col0, #T_709b3_row14_col1, #T_709b3_row14_col2, #T_709b3_row14_col3, #T_709b3_row14_col4, #T_709b3_row14_col5, #T_709b3_row14_col6, #T_709b3_row14_col7, #T_709b3_row15_col0, #T_709b3_row15_col1, #T_709b3_row15_col2, #T_709b3_row15_col3, #T_709b3_row15_col4, #T_709b3_row15_col5, #T_709b3_row15_col6, #T_709b3_row15_col7, #T_709b3_row16_col0, #T_709b3_row16_col1, #T_709b3_row16_col2, #T_709b3_row16_col3, #T_709b3_row16_col4, #T_709b3_row16_col5, #T_709b3_row16_col6, #T_709b3_row16_col7, #T_709b3_row17_col0, #T_709b3_row17_col1, #T_709b3_row17_col2, #T_709b3_row17_col3, #T_709b3_row17_col4, #T_709b3_row17_col5, #T_709b3_row17_col6, #T_709b3_row17_col7, #T_709b3_row18_col0, #T_709b3_row18_col1, #T_709b3_row18_col2, #T_709b3_row18_col3, #T_709b3_row18_col4, #T_709b3_row18_col5, #T_709b3_row18_col6, #T_709b3_row18_col7, #T_709b3_row19_col0, #T_709b3_row19_col1, #T_709b3_row19_col2, #T_709b3_row19_col3, #T_709b3_row19_col4, #T_709b3_row19_col5, #T_709b3_row19_col6, #T_709b3_row19_col7, #T_709b3_row20_col0, #T_709b3_row20_col1, #T_709b3_row20_col2, #T_709b3_row20_col3, #T_709b3_row20_col4, #T_709b3_row20_col5, #T_709b3_row20_col6, #T_709b3_row20_col7, #T_709b3_row21_col0, #T_709b3_row21_col1, #T_709b3_row21_col2, #T_709b3_row21_col3, #T_709b3_row21_col4, #T_709b3_row21_col5, #T_709b3_row21_col6, #T_709b3_row21_col7, #T_709b3_row22_col0, #T_709b3_row22_col1, #T_709b3_row22_col2, #T_709b3_row22_col3, #T_709b3_row22_col4, #T_709b3_row22_col5, #T_709b3_row22_col6, #T_709b3_row22_col7, #T_709b3_row23_col0, #T_709b3_row23_col1, #T_709b3_row23_col2, #T_709b3_row23_col3, #T_709b3_row23_col4, #T_709b3_row23_col5, #T_709b3_row23_col6, #T_709b3_row23_col7, #T_709b3_row24_col0, #T_709b3_row24_col1, #T_709 ...

# %% [markdown]
# <h3 style="color: #7aa2f7; font-weight: bold;">Data Enrichment</h3>
#
# <div style="
#   color: #9aa5ce;
#   font-family: Fira Code;
#   font-weight: 500;
# ">
# <li>Removing the which contain null or none value in column `Genres` and `Studio` as it cannot be replace with other values.</li>
# <li>Convert the value of column `Genres` and `Studio` to lower case</li>
#
# </div>

# %%
# None value contain in Studio column
dataset_studio_none_val = updated_required_dataset["Studio"].apply(lambda x: 'none' in x)
rr_display(updated_required_dataset[dataset_studio_none_val])
# Out:
# <style type="text/css">
# #T_007f3 th {
#   text-align: left;
# }
# #T_007f3_row0_col0, #T_007f3_row0_col1, #T_007f3_row0_col2, #T_007f3_row0_col3, #T_007f3_row0_col4, #T_007f3_row0_col5, #T_007f3_row0_col6, #T_007f3_row0_col7, #T_007f3_row1_col0, #T_007f3_row1_col1, #T_007f3_row1_col2, #T_007f3_row1_col3, #T_007f3_row1_col4, #T_007f3_row1_col5, #T_007f3_row1_col6, #T_007f3_row1_col7, #T_007f3_row2_col0, #T_007f3_row2_col1, #T_007f3_row2_col2, #T_007f3_row2_col3, #T_007f3_row2_col4, #T_007f3_row2_col5, #T_007f3_row2_col6, #T_007f3_row2_col7, #T_007f3_row3_col0, #T_007f3_row3_col1, #T_007f3_row3_col2, #T_007f3_row3_col3, #T_007f3_row3_col4, #T_007f3_row3_col5, #T_007f3_row3_col6, #T_007f3_row3_col7, #T_007f3_row4_col0, #T_007f3_row4_col1, #T_007f3_row4_col2, #T_007f3_row4_col3, #T_007f3_row4_col4, #T_007f3_row4_col5, #T_007f3_row4_col6, #T_007f3_row4_col7, #T_007f3_row5_col0, #T_007f3_row5_col1, #T_007f3_row5_col2, #T_007f3_row5_col3, #T_007f3_row5_col4, #T_007f3_row5_col5, #T_007f3_row5_col6, #T_007f3_row5_col7, #T_007f3_row6_col0, #T_007f3_row6_col1, #T_007f3_row6_col2, #T_007f3_row6_col3, #T_007f3_row6_col4, #T_007f3_row6_col5, #T_007f3_row6_col6, #T_007f3_row6_col7, #T_007f3_row7_col0, #T_007f3_row7_col1, #T_007f3_row7_col2, #T_007f3_row7_col3, #T_007f3_row7_col4, #T_007f3_row7_col5, #T_007f3_row7_col6, #T_007f3_row7_col7, #T_007f3_row8_col0, #T_007f3_row8_col1, #T_007f3_row8_col2, #T_007f3_row8_col3, #T_007f3_row8_col4, #T_007f3_row8_col5, #T_007f3_row8_col6, #T_007f3_row8_col7, #T_007f3_row9_col0, #T_007f3_row9_col1, #T_007f3_row9_col2, #T_007f3_row9_col3, #T_007f3_row9_col4, #T_007f3_row9_col5, #T_007f3_row9_col6, #T_007f3_row9_col7, #T_007f3_row10_col0, #T_007f3_row10_col1, #T_007f3_row10_col2, #T_007f3_row10_col3, #T_007f3_row10_col4, #T_007f3_row10_col5, #T_007f3_row10_col6, #T_007f3_row10_col7, #T_007f3_row11_col0, #T_007f3_row11_col1, #T_007f3_row11_col2, #T_007f3_row11_col3, #T_007f3_row11_col4, #T_007f3_row11_col5, #T_007f3_row11_col6, #T_007f3_row11_col7, #T_007f3_row12_col0, #T_007f3_row12_col1, #T_007f3_row12_col2, #T_007f3_row12_col3, #T_007f3_row12_col4, #T_007f3_row12_col5, #T_007f3_row12_col6, #T_007f3_row12_col7, #T_007f3_row13_col0, #T_007f3_row13_col1, #T_007f3_row13_col2, #T_007f3_row13_col3, #T_007f3_row13_col4, #T_007f3_row13_col5, #T_007f3_row13_col6, #T_007f3_row13_col7, #T_007f3_row14_col0, #T_007f3_row14_col1, #T_007f3_row14_col2, #T_007f3_row14_col3, #T_007f3_row14_col4, #T_007f3_row14_col5, #T_007f3_row14_col6, #T_007f3_row14_col7, #T_007f3_row15_col0, #T_007f3_row15_col1, #T_007f3_row15_col2, #T_007f3_row15_col3, #T_007f3_row15_col4, #T_007f3_row15_col5, #T_007f3_row15_col6, #T_007f3_row15_col7, #T_007f3_row16_col0, #T_007f3_row16_col1, #T_007f3_row16_col2, #T_007f3_row16_col3, #T_007f3_row16_col4, #T_007f3_row16_col5, #T_007f3_row16_col6, #T_007f3_row16_col7, #T_007f3_row17_col0, #T_007f3_row17_col1, #T_007f3_row17_col2, #T_007f3_row17_col3, #T_007f3_row17_col4, #T_007f3_row17_col5, #T_007f3_row17_col6, #T_007f3_row17_col7, #T_007f3_row18_col0, #T_007f3_row18_col1, #T_007f3_row18_col2, #T_007f3_row18_col3, #T_007f3_row18_col4, #T_007f3_row18_col5, #T_007f3_row18_col6, #T_007f3_row18_col7, #T_007f3_row19_col0, #T_007f3_row19_col1, #T_007f3_row19_col2, #T_007f3_row19_col3, #T_007f3_row19_col4, #T_007f3_row19_col5, #T_007f3_row19_col6, #T_007f3_row19_col7, #T_007f3_row20_col0, #T_007f3_row20_col1, #T_007f3_row20_col2, #T_007f3_row20_col3, #T_007f3_row20_col4, #T_007f3_row20_col5, #T_007f3_row20_col6, #T_007f3_row20_col7, #T_007f3_row21_col0, #T_007f3_row21_col1, #T_007f3_row21_col2, #T_007f3_row21_col3, #T_007f3_row21_col4, #T_007f3_row21_col5, #T_007f3_row21_col6, #T_007f3_row21_col7, #T_007f3_row22_col0, #T_007f3_row22_col1, #T_007f3_row22_col2, #T_007f3_row22_col3, #T_007f3_row22_col4, #T_007f3_row22_col5, #T_007f3_row22_col6, #T_007f3_row22_col7, #T_007f3_row23_col0, #T_007f3_row23_col1, #T_007f3_row23_col2, #T_007f3_row23_col3, #T_007f3_row23_col4, #T_007f3_row23_col5, #T_007f3_row23_col6, #T_007f3_row23_col7, #T_007f3_row24_col0, #T_007f3_row24_col1, #T_007 ...

# %%
none_val_studio_genres = list(set(updated_required_dataset[dataset_studio_none_val].index.append(updated_required_dataset[dataset_genres_none_val].index)))
print(none_val_studio_genres)
# Out:
# [1546, 1041, 1044, 1559, 1565, 552, 1065, 558, 51, 1591, 1607, 1608, 1097, 591, 81, 1107, 596, 1621, 1627, 611, 1635, 1638, 1126, 621, 623, 1139, 1148, 1661, 1662, 1669, 141, 1677, 1683, 151, 1691, 1183, 677, 1195, 180, 1216, 197, 1734, 1224, 1738, 1759, 224, 1248, 748, 756, 763, 1799, 1290, 268, 270, 1295, 1810, 788, 1309, 292, 1329, 1844, 823, 831, 1862, 847, 1875, 1886, 352, 1380, 1383, 1385, 1387, 1403, 1404, 1927, 903, 907, 1931, 912, 431, 1970, 1460, 954, 1487, 479, 1513, 497, 1522, 1523, 1532, 509]

# %%
updated_required_dataset = updated_required_dataset.drop(none_val_studio_genres)
rr_display(updated_required_dataset.head())
# Out:
# <style type="text/css">
# #T_79fbe th {
#   text-align: left;
# }
# #T_79fbe_row0_col0, #T_79fbe_row0_col1, #T_79fbe_row0_col2, #T_79fbe_row0_col3, #T_79fbe_row0_col4, #T_79fbe_row0_col5, #T_79fbe_row0_col6, #T_79fbe_row0_col7, #T_79fbe_row1_col0, #T_79fbe_row1_col1, #T_79fbe_row1_col2, #T_79fbe_row1_col3, #T_79fbe_row1_col4, #T_79fbe_row1_col5, #T_79fbe_row1_col6, #T_79fbe_row1_col7, #T_79fbe_row2_col0, #T_79fbe_row2_col1, #T_79fbe_row2_col2, #T_79fbe_row2_col3, #T_79fbe_row2_col4, #T_79fbe_row2_col5, #T_79fbe_row2_col6, #T_79fbe_row2_col7, #T_79fbe_row3_col0, #T_79fbe_row3_col1, #T_79fbe_row3_col2, #T_79fbe_row3_col3, #T_79fbe_row3_col4, #T_79fbe_row3_col5, #T_79fbe_row3_col6, #T_79fbe_row3_col7, #T_79fbe_row4_col0, #T_79fbe_row4_col1, #T_79fbe_row4_col2, #T_79fbe_row4_col3, #T_79fbe_row4_col4, #T_79fbe_row4_col5, #T_79fbe_row4_col6, #T_79fbe_row4_col7 {
#   text-align: left;
# }
# </style>
# <table id="T_79fbe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_79fbe_level0_col0" class="col_heading level0 col0" >Name</th>
#       <th id="T_79fbe_level0_col1" class="col_heading level0 col1" >Genres</th>
#       <th id="T_79fbe_level0_col2" class="col_heading level0 col2" >Studio</th>
#       <th id="T_79fbe_level0_col3" class="col_heading level0 col3" >Type</th>
#       <th id="T_79fbe_level0_col4" class="col_heading level0 col4" >Score</th>
#       <th id="T_79fbe_level0_col5" class="col_heading level0 col5" >Score Rank</th>
#       <th id="T_79fbe_level0_col6" class="col_heading level0 col6" >Num. of episodes</th>
#       <th id="T_79fbe_level0_col7" class="col_heading level0 col7" >Popularity Rank</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_79fbe_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_79fbe_row0_col0" class="data row0 col0" >Fullmetal Alchemist: Brotherhood</td>
#       <td id="T_79fbe_row0_col1" class="data row0 col1" >['action', 'adventure', 'drama', 'fantasy']</td>
#       <td id="T_79fbe_row0_col2" class="data row0 col2" >['bones']</td>
#       <td id="T_79fbe_row0_col3" class="data row0 col3" >tv</td>
#       <td id="T_79fbe_row0_col4" class="data row0 col4" >9.140000</td>
#       <td id="T_79fbe_row0_col5" class="data row0 col5" >1</td>
#       <td id="T_79fbe_row0_col6" class="data row0 col6" >64</td>
#       <td id="T_79fbe_row0_col7" class="data row0 col7" >3</td>
#     </tr>
#     <tr>
#       <th id="T_79fbe_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_79fbe_row1_col0" class="data row1 col0" >Spy x Family</td>
#       <td id="T_79fbe_row1_col1" class="data row1 col1" >['action', 'comedy']</td>
#       <td id="T_79fbe_row1_col2" class="data row1 col2" >['wit studio', 'cloverworks']</td>
#       <td id="T_79fbe_row1_col3" class="data row1 col3" >tv</td>
#       <td id="T_79fbe_row1_col4" class="data row1 col4" >9.090000</td>
#       <td id="T_79fbe_row1_col5" class="data row1 col5" >2</td>
#       <td id="T_79fbe_row1_col6" class="data row1 col6" >12</td>
#       <td id="T_79fbe_row1_col7" class="data row1 col7" >350</td>
#     </tr>
#     <tr>
#       <th id="T_79fbe_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_79fbe_row2_col0" class="data row2 col0" >Shingeki no Kyojin Season 3 Part 2</td>
#       <td id="T_79fbe_row2_col1" class="data row2 col1" >['action', 'drama']</td>
#       <td id="T_79fbe_row2_col2" class="data row2 col2" >['wit studio']</td>
#       <td id="T_79fbe_row2_col3" class="data row2 col3" >tv</td>
#       <td id="T_79fbe_row2_col4" class="data row2 col4" >9.080000</td>
#       <td id="T_79fbe_row2_col5" class="data row2 col5" >3</td>
#       <td id="T_79fbe_row2_col6" class="data row2 col6" >10</td>
#       <td id="T_79fbe_row2_col7" class="data row2 col7" >32</td>
#     </tr>
#     <tr>
#       <th id="T_79fbe_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_79fbe_row3_col0" class="data row3 col0" >Steins;Gate</td>
#       <td id="T_79fbe_row3_col1" class="data row3 col1" >['drama', 'sci-fi', 'suspense']</td>
#       <td id="T_79fbe_row3_col2" class="data row3 col2" >['white fox']</td>
#       <td id="T_79fbe_row3_col3" class="data row3 col3" >tv</td>
#       <td id="T_79fbe_row3_col4" class="data row3 col4" >9.080000</td>
#       <td id="T_79fbe_row3_col5" class="data row3 col5" >4</td>
#       <td id="T_79fbe_row3_col6" class="data row3 col6" >24</td>
#       <td id="T_79fbe_row3_col7" class="data row3 col7" >13</td>
#     </tr>
#     <tr>
#       <th id="T_79fbe_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_79fbe_row4_col0" class="data row4 col0" >Gintama°</td>
#       <td id="T_79fbe_row4_col1" class="data row4 col1" >['action', 'comedy', 'sci-fi']</td>
#       <td id="T_79fbe_row4_col2" class="data row4 col2" >['bandai namco pictures']</td>
#       <td id="T_79fbe_row4_col3" class="data row4 col3" >tv</td>
#       <td id="T_79fbe_row4_col4" class="data row4 col4" >9.080000</td>
#       <td id="T_79fbe_row4_col5" class="data row4 col5" >5</td>
#       <td id="T_79fbe_row4_col6" class="data row4 col6" >51</td>
#       <td id="T_79fbe_row4_col7" class="data row4 col7" >335</td>
#     </tr>
#   </tbody>
# </table>

# %%
updated_required_dataset.isnull().sum()
# Out:
# Name                0
# Genres              0
# Studio              0
# Type                0
# Score               0
# Score Rank          0
# Num. of episodes    0
# Popularity Rank     0
# dtype: int64

# %% [markdown]
# <h3 style="color: #7aa2f7; font-weight: bold;">Data Export</h3>
#
#
# <div style="
#   color: #9aa5ce;
#   font-family: Fira Code;
#   font-weight: 500;
# ">
# Export updated dataset to new file <code style="color:#7aa">rr_anime_info.csv</code> for further use in data validation.
# </div>

# %%
# export
updated_required_dataset.to_csv("dataset/rr_anime_info.csv", index = False)
