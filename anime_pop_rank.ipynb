# %% [markdown]
# <h3 style="color: #7aa2f7; font-weight: bold;" align="center">Anime Popularity Rank</h3>

# %% [markdown]
# <h4 style="color: #7aa2f7; font-weight: bold;">Import Libraries</h4>

# %%
from library import pd_read_csv, pd_dataframe,  pd_eval, pd_get_dummies
from library import sk_shuffle, sk_train_test_split, sk_logistic_regression
from core import rr_display, rr_unique, rr_encoding, rr_to_series

# %%
# Import the update dataset
rr_anime_dataset = pd_read_csv("dataset/rr_anime_info.csv", converters={'Genres': pd_eval, 'Studio': pd_eval})

# %%
rr_display(rr_anime_dataset.head())
# Out:
# <style type="text/css">
# #T_d99a6 th {
#   text-align: left;
# }
# #T_d99a6_row0_col0, #T_d99a6_row0_col1, #T_d99a6_row0_col2, #T_d99a6_row0_col3, #T_d99a6_row0_col4, #T_d99a6_row0_col5, #T_d99a6_row0_col6, #T_d99a6_row0_col7, #T_d99a6_row1_col0, #T_d99a6_row1_col1, #T_d99a6_row1_col2, #T_d99a6_row1_col3, #T_d99a6_row1_col4, #T_d99a6_row1_col5, #T_d99a6_row1_col6, #T_d99a6_row1_col7, #T_d99a6_row2_col0, #T_d99a6_row2_col1, #T_d99a6_row2_col2, #T_d99a6_row2_col3, #T_d99a6_row2_col4, #T_d99a6_row2_col5, #T_d99a6_row2_col6, #T_d99a6_row2_col7, #T_d99a6_row3_col0, #T_d99a6_row3_col1, #T_d99a6_row3_col2, #T_d99a6_row3_col3, #T_d99a6_row3_col4, #T_d99a6_row3_col5, #T_d99a6_row3_col6, #T_d99a6_row3_col7, #T_d99a6_row4_col0, #T_d99a6_row4_col1, #T_d99a6_row4_col2, #T_d99a6_row4_col3, #T_d99a6_row4_col4, #T_d99a6_row4_col5, #T_d99a6_row4_col6, #T_d99a6_row4_col7 {
#   text-align: left;
# }
# </style>
# <table id="T_d99a6">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d99a6_level0_col0" class="col_heading level0 col0" >Name</th>
#       <th id="T_d99a6_level0_col1" class="col_heading level0 col1" >Genres</th>
#       <th id="T_d99a6_level0_col2" class="col_heading level0 col2" >Studio</th>
#       <th id="T_d99a6_level0_col3" class="col_heading level0 col3" >Type</th>
#       <th id="T_d99a6_level0_col4" class="col_heading level0 col4" >Score</th>
#       <th id="T_d99a6_level0_col5" class="col_heading level0 col5" >Score Rank</th>
#       <th id="T_d99a6_level0_col6" class="col_heading level0 col6" >Num. of episodes</th>
#       <th id="T_d99a6_level0_col7" class="col_heading level0 col7" >Popularity Rank</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d99a6_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d99a6_row0_col0" class="data row0 col0" >Fullmetal Alchemist: Brotherhood</td>
#       <td id="T_d99a6_row0_col1" class="data row0 col1" >['action', 'adventure', 'drama', 'fantasy']</td>
#       <td id="T_d99a6_row0_col2" class="data row0 col2" >['bones']</td>
#       <td id="T_d99a6_row0_col3" class="data row0 col3" >tv</td>
#       <td id="T_d99a6_row0_col4" class="data row0 col4" >9.140000</td>
#       <td id="T_d99a6_row0_col5" class="data row0 col5" >1</td>
#       <td id="T_d99a6_row0_col6" class="data row0 col6" >64</td>
#       <td id="T_d99a6_row0_col7" class="data row0 col7" >3</td>
#     </tr>
#     <tr>
#       <th id="T_d99a6_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_d99a6_row1_col0" class="data row1 col0" >Spy x Family</td>
#       <td id="T_d99a6_row1_col1" class="data row1 col1" >['action', 'comedy']</td>
#       <td id="T_d99a6_row1_col2" class="data row1 col2" >['wit studio', 'cloverworks']</td>
#       <td id="T_d99a6_row1_col3" class="data row1 col3" >tv</td>
#       <td id="T_d99a6_row1_col4" class="data row1 col4" >9.090000</td>
#       <td id="T_d99a6_row1_col5" class="data row1 col5" >2</td>
#       <td id="T_d99a6_row1_col6" class="data row1 col6" >12</td>
#       <td id="T_d99a6_row1_col7" class="data row1 col7" >350</td>
#     </tr>
#     <tr>
#       <th id="T_d99a6_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_d99a6_row2_col0" class="data row2 col0" >Shingeki no Kyojin Season 3 Part 2</td>
#       <td id="T_d99a6_row2_col1" class="data row2 col1" >['action', 'drama']</td>
#       <td id="T_d99a6_row2_col2" class="data row2 col2" >['wit studio']</td>
#       <td id="T_d99a6_row2_col3" class="data row2 col3" >tv</td>
#       <td id="T_d99a6_row2_col4" class="data row2 col4" >9.080000</td>
#       <td id="T_d99a6_row2_col5" class="data row2 col5" >3</td>
#       <td id="T_d99a6_row2_col6" class="data row2 col6" >10</td>
#       <td id="T_d99a6_row2_col7" class="data row2 col7" >32</td>
#     </tr>
#     <tr>
#       <th id="T_d99a6_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_d99a6_row3_col0" class="data row3 col0" >Steins;Gate</td>
#       <td id="T_d99a6_row3_col1" class="data row3 col1" >['drama', 'sci-fi', 'suspense']</td>
#       <td id="T_d99a6_row3_col2" class="data row3 col2" >['white fox']</td>
#       <td id="T_d99a6_row3_col3" class="data row3 col3" >tv</td>
#       <td id="T_d99a6_row3_col4" class="data row3 col4" >9.080000</td>
#       <td id="T_d99a6_row3_col5" class="data row3 col5" >4</td>
#       <td id="T_d99a6_row3_col6" class="data row3 col6" >24</td>
#       <td id="T_d99a6_row3_col7" class="data row3 col7" >13</td>
#     </tr>
#     <tr>
#       <th id="T_d99a6_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_d99a6_row4_col0" class="data row4 col0" >Gintama°</td>
#       <td id="T_d99a6_row4_col1" class="data row4 col1" >['action', 'comedy', 'sci-fi']</td>
#       <td id="T_d99a6_row4_col2" class="data row4 col2" >['bandai namco pictures']</td>
#       <td id="T_d99a6_row4_col3" class="data row4 col3" >tv</td>
#       <td id="T_d99a6_row4_col4" class="data row4 col4" >9.080000</td>
#       <td id="T_d99a6_row4_col5" class="data row4 col5" >5</td>
#       <td id="T_d99a6_row4_col6" class="data row4 col6" >51</td>
#       <td id="T_d99a6_row4_col7" class="data row4 col7" >335</td>
#     </tr>
#   </tbody>
# </table>

# %%
rr_to_series(rr_anime_dataset["Genres"], True).value_counts()
# Out:
# comedy           809
# action           726
# drama            591
# fantasy          462
# adventure        427
# romance          413
# slice of life    377
# supernatural     366
# sci-fi           342
# mystery          228
# sports           126
# suspense          60
# ecchi             52
# horror            45
# boys love         21
# gourmet           20
# girls love        17
# avant garde       12
# award winning      2
# dtype: int64

# %% [markdown]
# <h4 style="color: #7aa2f7; font-weight: bold;">Data Validation</h4>
#
# <div style="
#   color: #9aa5ce;
#   font-family: Fira Code;
#   font-weight: 500;
# ">
# Splitting the data
# </div>

# %%
# not required column
rr_anime_dataset_name = pd_dataframe(rr_anime_dataset.iloc[:,0])
rr_display(rr_anime_dataset_name.head())
# Out:
# <style type="text/css">
# #T_3be9c th {
#   text-align: left;
# }
# #T_3be9c_row0_col0, #T_3be9c_row1_col0, #T_3be9c_row2_col0, #T_3be9c_row3_col0, #T_3be9c_row4_col0 {
#   text-align: left;
# }
# </style>
# <table id="T_3be9c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3be9c_level0_col0" class="col_heading level0 col0" >Name</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3be9c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_3be9c_row0_col0" class="data row0 col0" >Fullmetal Alchemist: Brotherhood</td>
#     </tr>
#     <tr>
#       <th id="T_3be9c_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_3be9c_row1_col0" class="data row1 col0" >Spy x Family</td>
#     </tr>
#     <tr>
#       <th id="T_3be9c_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_3be9c_row2_col0" class="data row2 col0" >Shingeki no Kyojin Season 3 Part 2</td>
#     </tr>
#     <tr>
#       <th id="T_3be9c_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_3be9c_row3_col0" class="data row3 col0" >Steins;Gate</td>
#     </tr>
#     <tr>
#       <th id="T_3be9c_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_3be9c_row4_col0" class="data row4 col0" >Gintama°</td>
#     </tr>
#   </tbody>
# </table>

# %%
X = rr_anime_dataset.iloc[:, 1:7]
rr_display(X.head())
# Out:
# <style type="text/css">
# #T_e6c2d th {
#   text-align: left;
# }
# #T_e6c2d_row0_col0, #T_e6c2d_row0_col1, #T_e6c2d_row0_col2, #T_e6c2d_row0_col3, #T_e6c2d_row0_col4, #T_e6c2d_row0_col5, #T_e6c2d_row1_col0, #T_e6c2d_row1_col1, #T_e6c2d_row1_col2, #T_e6c2d_row1_col3, #T_e6c2d_row1_col4, #T_e6c2d_row1_col5, #T_e6c2d_row2_col0, #T_e6c2d_row2_col1, #T_e6c2d_row2_col2, #T_e6c2d_row2_col3, #T_e6c2d_row2_col4, #T_e6c2d_row2_col5, #T_e6c2d_row3_col0, #T_e6c2d_row3_col1, #T_e6c2d_row3_col2, #T_e6c2d_row3_col3, #T_e6c2d_row3_col4, #T_e6c2d_row3_col5, #T_e6c2d_row4_col0, #T_e6c2d_row4_col1, #T_e6c2d_row4_col2, #T_e6c2d_row4_col3, #T_e6c2d_row4_col4, #T_e6c2d_row4_col5 {
#   text-align: left;
# }
# </style>
# <table id="T_e6c2d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e6c2d_level0_col0" class="col_heading level0 col0" >Genres</th>
#       <th id="T_e6c2d_level0_col1" class="col_heading level0 col1" >Studio</th>
#       <th id="T_e6c2d_level0_col2" class="col_heading level0 col2" >Type</th>
#       <th id="T_e6c2d_level0_col3" class="col_heading level0 col3" >Score</th>
#       <th id="T_e6c2d_level0_col4" class="col_heading level0 col4" >Score Rank</th>
#       <th id="T_e6c2d_level0_col5" class="col_heading level0 col5" >Num. of episodes</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e6c2d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e6c2d_row0_col0" class="data row0 col0" >['action', 'adventure', 'drama', 'fantasy']</td>
#       <td id="T_e6c2d_row0_col1" class="data row0 col1" >['bones']</td>
#       <td id="T_e6c2d_row0_col2" class="data row0 col2" >tv</td>
#       <td id="T_e6c2d_row0_col3" class="data row0 col3" >9.140000</td>
#       <td id="T_e6c2d_row0_col4" class="data row0 col4" >1</td>
#       <td id="T_e6c2d_row0_col5" class="data row0 col5" >64</td>
#     </tr>
#     <tr>
#       <th id="T_e6c2d_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_e6c2d_row1_col0" class="data row1 col0" >['action', 'comedy']</td>
#       <td id="T_e6c2d_row1_col1" class="data row1 col1" >['wit studio', 'cloverworks']</td>
#       <td id="T_e6c2d_row1_col2" class="data row1 col2" >tv</td>
#       <td id="T_e6c2d_row1_col3" class="data row1 col3" >9.090000</td>
#       <td id="T_e6c2d_row1_col4" class="data row1 col4" >2</td>
#       <td id="T_e6c2d_row1_col5" class="data row1 col5" >12</td>
#     </tr>
#     <tr>
#       <th id="T_e6c2d_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_e6c2d_row2_col0" class="data row2 col0" >['action', 'drama']</td>
#       <td id="T_e6c2d_row2_col1" class="data row2 col1" >['wit studio']</td>
#       <td id="T_e6c2d_row2_col2" class="data row2 col2" >tv</td>
#       <td id="T_e6c2d_row2_col3" class="data row2 col3" >9.080000</td>
#       <td id="T_e6c2d_row2_col4" class="data row2 col4" >3</td>
#       <td id="T_e6c2d_row2_col5" class="data row2 col5" >10</td>
#     </tr>
#     <tr>
#       <th id="T_e6c2d_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_e6c2d_row3_col0" class="data row3 col0" >['drama', 'sci-fi', 'suspense']</td>
#       <td id="T_e6c2d_row3_col1" class="data row3 col1" >['white fox']</td>
#       <td id="T_e6c2d_row3_col2" class="data row3 col2" >tv</td>
#       <td id="T_e6c2d_row3_col3" class="data row3 col3" >9.080000</td>
#       <td id="T_e6c2d_row3_col4" class="data row3 col4" >4</td>
#       <td id="T_e6c2d_row3_col5" class="data row3 col5" >24</td>
#     </tr>
#     <tr>
#       <th id="T_e6c2d_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_e6c2d_row4_col0" class="data row4 col0" >['action', 'comedy', 'sci-fi']</td>
#       <td id="T_e6c2d_row4_col1" class="data row4 col1" >['bandai namco pictures']</td>
#       <td id="T_e6c2d_row4_col2" class="data row4 col2" >tv</td>
#       <td id="T_e6c2d_row4_col3" class="data row4 col3" >9.080000</td>
#       <td id="T_e6c2d_row4_col4" class="data row4 col4" >5</td>
#       <td id="T_e6c2d_row4_col5" class="data row4 col5" >51</td>
#     </tr>
#   </tbody>
# </table>

# %%
y = rr_anime_dataset.iloc[:, 7]
y
# Out:
# 0          3
# 1        350
# 2         32
# 3         13
# 4        335
#         ...
# 1904    1766
# 1905    1748
# 1906    5610
# 1907    3394
# 1908    3908
# Name: Popularity Rank, Length: 1909, dtype: int64

# %%
X_studio_unique = rr_unique(X["Studio"])
X_studio_unique.head(), len(X_studio_unique)
# Out:
# (0                    bones
#  1               wit studio
#  2              cloverworks
#  3                white fox
#  4    bandai namco pictures
#  dtype: object,
#  220)

# %%
X_genres_unique = rr_unique(X["Genres"])
X_genres_unique.head(), len(X_genres_unique)
# Out:
# (0       action
#  1    adventure
#  2        drama
#  3      fantasy
#  4       comedy
#  dtype: object,
#  19)

# %%
rr_unique(X["Type"]), len(rr_unique(X["Type"]))
# Out:
# (0         tv
#  1      movie
#  2        ova
#  3        ona
#  4    special
#  5      music
#  dtype: object,
#  6)

# %%
X = rr_encoding(X, "Genres")
X = rr_encoding(X, "Studio")
X = pd_get_dummies(X,columns=["Type"], prefix="Type")
print(X.columns)
# Out:
# Index(['Score', 'Score Rank', 'Num. of episodes', 'Genres_action',
#        'Genres_adventure', 'Genres_avant garde', 'Genres_award winning',
#        'Genres_boys love', 'Genres_comedy', 'Genres_drama',
#        ...
#        'Studio_yokohama animation lab', 'Studio_yumeta company',
#        'Studio_zero-g', 'Studio_zexcs', 'Type_movie', 'Type_music', 'Type_ona',
#        'Type_ova', 'Type_special', 'Type_tv'],
#       dtype='object', length=248)

# %% [markdown]
# <h3 style="color: #7aa2f7; font-weight: bold;">Data Export</h3>
#
#
# <div style="
#   color: #9aa5ce;
#   font-family: Fira Code;
#   font-weight: 500;
# ">
# Export final updated `X dataset` to new file <code style="color:#7aa">rr_anime_x_dataset.csv</code>.<br/>
# Export final updated `y dataset` to new file <code style="color:#7aa">rr_anime_y_dataset.csv</code>.
# </div>

# %%
X.to_csv("dataset/rr_anime_x_dataset.csv", index = False)
y.to_csv("dataset/rr_anime_y_dataset.csv", index = False)

# %%
rr_display(X.head())
# Out:
# <style type="text/css">
# #T_03078 th {
#   text-align: left;
# }
# #T_03078_row0_col0, #T_03078_row0_col1, #T_03078_row0_col2, #T_03078_row0_col3, #T_03078_row0_col4, #T_03078_row0_col5, #T_03078_row0_col6, #T_03078_row0_col7, #T_03078_row0_col8, #T_03078_row0_col9, #T_03078_row0_col10, #T_03078_row0_col11, #T_03078_row0_col12, #T_03078_row0_col13, #T_03078_row0_col14, #T_03078_row0_col15, #T_03078_row0_col16, #T_03078_row0_col17, #T_03078_row0_col18, #T_03078_row0_col19, #T_03078_row0_col20, #T_03078_row0_col21, #T_03078_row0_col22, #T_03078_row0_col23, #T_03078_row0_col24, #T_03078_row0_col25, #T_03078_row0_col26, #T_03078_row0_col27, #T_03078_row0_col28
161, #T_03078_row0_col162, #T_03078_row0_col163, #T_03078_row0_col164, #T_03078_row0_col165, #T_03078_row0_col166, #T_03078_row0_col167, #T_03078_row0_col168, #T_03078_row0_col169, #T_03078_row0_col170, #T_03078_row0_col171, #T_03078_row0_col172, #T_03078_row0_col173, #T_03078_row0_col174, #T_03078_row0_col175, #T_03078_row0_col176, #T_03078_row0_col177, #T_03078_row0_col178, #T_03078_row0_col179, #T_03078_row0_col180, #T_03078_row0_col181, #T_03078_row0_col182, #T_03078_row0_col183, #T_03078_row0_col184, #T_03078_row0_col185, #T_03078_row0_col1 ...

# %%
X_train, X_test, y_train, y_test = sk_train_test_split(X, y, test_size=0.25, random_state=7)

# %%
rr_display(X_train.head())
# Out:
# <style type="text/css">
# #T_2be8d th {
#   text-align: left;
# }
# #T_2be8d_row0_col0, #T_2be8d_row0_col1, #T_2be8d_row0_col2, #T_2be8d_row0_col3, #T_2be8d_row0_col4, #T_2be8d_row0_col5, #T_2be8d_row0_col6, #T_2be8d_row0_col7, #T_2be8d_row0_col8, #T_2be8d_row0_col9, #T_2be8d_row0_col10, #T_2be8d_row0_col11, #T_2be8d_row0_col12, #T_2be8d_row0_col13, #T_2be8d_row0_col14, #T_2be8d_row0_col15, #T_2be8d_row0_col16, #T_2be8d_row0_col17, #T_2be8d_row0_col18, #T_2be8d_row0_col19, #T_2be8d_row0_col20, #T_2be8d_row0_col21, #T_2be8d_row0_col22, #T_2be8d_row0_col23, #T_2be8d_row0_col24, #T_2be8d_row0_col25, #T_2be8d_row0_col26, #T_2be8d_row0_col27, #T_2be8d_row0_col28, #T_2be8d_row0_col29, #T_2be8d_row0_col30, #T_2be8d_row0_col31, #T_2be8d_row0_col32, #T_2be8d_row0_col33, #T_2be8d_row0_col34, #T_2be8d_row0_col35, #T_2be8d_row0_col36, #T_2be8d_row0_col37, #T_2be8d_row0_col38, #T_2be8d_row0_col39, #T_2be8d_row0_col40, #T_2be8d_row0_col41, #T_2be8d_row0_col42, #T_2be8d_row0_col43, #T_2be8d_row0_col44, #T_2be8d_row0_col45, #T_2be8d_row0_col46, #T_2be8d_row0_col47, #T_2be8d_row0_col48, #T_2be8d_row0_col49, #T_2be8d_row0_col50, #T_2be8d_row0_col51, #T_2be8d_row0_col52, #T_2be8d_row0_col53, #T_2be8d_row0_col54, #T_2be8d_row0_col55, #T_2be8d_row0_col56, #T_2be8d_row0_col57, #T_2be8d_row0_col58, #T_2be8d_row0_col59, #T_2be8d_row0_col60, #T_2be8d_row0_col61, #T_2be8d_row0_col62, #T_2be8d_row0_col63, #T_2be8d_row0_col64, #T_2be8d_row0_col65, #T_2be8d_row0_col66, #T_2be8d_row0_col67, #T_2be8d_row0_col68, #T_2be8d_row0_col69, #T_2be8d_row0_col70, #T_2be8d_row0_col71, #T_2be8d_row0_col72, #T_2be8d_row0_col73, #T_2be8d_row0_col74, #T_2be8d_row0_col75, #T_2be8d_row0_col76, #T_2be8d_row0_col77, #T_2be8d_row0_col78, #T_2be8d_row0_col79, #T_2be8d_row0_col80, #T_2be8d_row0_col81, #T_2be8d_row0_col82, #T_2be8d_row0_col83, #T_2be8d_row0_